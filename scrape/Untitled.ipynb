# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime


# edit these three variables
user = 'realdonaldtrump'
start = datetime.datetime(2010, 1, 1)  # year, month, day
end = datetime.datetime(2019, 11, 10)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()


# don't mess with this stuff
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item'
user = user.lower()
ids = []

def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?f=tweets&vertical=default&q=from%3A'
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))

        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)


try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))
except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
driver.close()
# Out:
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-01%20until%3A2010-01-02include%3Aretweets&src=typd
# 2010-01-01
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-02%20until%3A2010-01-03include%3Aretweets&src=typd
# 2010-01-02
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-03%20until%3A2010-01-04include%3Aretweets&src=typd
# 2010-01-03
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-04%20until%3A2010-01-05include%3Aretweets&src=typd
# 2010-01-04
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-05%20until%3A2010-01-06include%3Aretweets&src=typd
# 2010-01-05
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-06%20until%3A2010-01-07include%3Aretweets&src=typd
# 2010-01-06
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-07%20until%3A2010-01-08include%3Aretweets&src=typd
# 2010-01-07
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-08%20until%3A2010-01-09include%3Aretweets&src=typd
# 2010-01-08
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-09%20until%3A2010-01-10include%3Aretweets&src=typd
# 2010-01-09
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-10%20until%3A2010-01-11include%3Aretweets&src=typd
# 2010-01-10
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01-11%20until%3A2010-01-12include%3Aretweets&src=typd
# 2010-01-11
# 0 tweets found, 0 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-01
total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-22%20until%3A2010-05-23include%3Aretweets&src=typd
# 2010-05-22
# 0 tweets found, 46 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-23%20until%3A2010-05-24include%3Aretweets&src=typd
# 2010-05-23
# 0 tweets found, 46 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-24%20until%3A2010-05-25include%3Aretweets&src=typd
# 2010-05-24
# 1 tweets found, 46 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-25%20until%3A2010-05-26include%3Aretweets&src=typd
# 2010-05-25
# 2 tweets found, 47 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-26%20until%3A2010-05-27include%3Aretweets&src=typd
# 2010-05-26
# 2 tweets found, 49 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-27%20until%3A2010-05-28include%3Aretweets&src=typd
# 2010-05-27
# 1 tweets found, 51 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-28%20until%3A2010-05-29include%3Aretweets&src=typd
# 2010-05-28
# 1 tweets found, 52 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-29%20until%3A2010-05-30include%3Aretweets&src=typd
# 2010-05-29
# 0 tweets found, 53 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-30%20until%3A2010-05-31include%3Aretweets&src=typd
# 2010-05-30
# 0 tweets found, 53 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-05-31%20until%3A2010-06-01include%3Aretweets&src=typd
# 2010-05-31
# 0 tweets found, 53 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-01%20until%3A2010-06-02include%3Aretweets&src=typd
# 2010-06-01
# 0 tweets found, 53 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-02%20until%3A2010-06-03include%3Aretweets&src=typd
# 2010-06-02
# 1 tweets found, 53 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-03%20until%3A2010-06-04include%3Aretweets&src=typd
# 2010-06-03
# 0 tweets found, 54 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-04%20until%3A2010-06-05include%3Aretweets&src=typd
# 2010-06-04
# 2 tweets found, 54 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-05%20until%3A2010-06-06include%3Aretweets&src=typd
# 2010-06-05
# 1 tweets found, 56 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-06%20until%3A2010-06-07include%3Aretweets&src=typd
# 2010-06-06
# 0 tweets found, 57 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-07%20until%3A2010-06-08include%3Aretweets&src=typd
# 2010-06-07
# 0 tweets found, 57 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-08%20until%3A2010-06-09include%3Aretweets&src=typd
# 2010-06-08
# 1 tweets found, 57 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-09%20until%3A2010-06-10include%3Aretweets&src=typd
# 2010-06-09
# 2 tweets found, 58 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-10%20until%3A2010-06-11include%3Aretweets&src=typd
# 2010-06-10
# 1 tweets found, 60 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-11%20until%3A2010-06-12include%3Aretweets&src=typd
# 2010-06-11
# 0 tweets found, 61 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-12%20until%3A2010-06-13include%3Aretweets&src=typd
# 2010-06-12
# 0 tweets found, 61 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-13%20until%3A2010-06-14include%3Aretweets&src=typd
# 2010-06-13
# 0 tweets found, 61 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-14%20until%3A2010-06-15include%3Aretweets&src=typd
# 2010-06-14
# 0 tweets found, 61 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-15%20until%3A2010-06-16include%3Aretweets&src=typd
# 2010-06-15
# 2 tweets found, 61 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-16%20until%3A2010-06-17include%3Aretweets&src=typd
# 2010-06-16
# 0 tweets found, 63 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-17%20until%3A2010-06-18include%3Aretweets&src=typd
# 2010-06-17
# 2 tweets found, 63 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-18%20until%3A2010-06-19include%3Aretweets&src=typd
# 2010-06-18
# 0 tweets found, 65 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-19%20until%3A2010-06-20include%3Aretweets&src=typd
# 2010-06-19
# 0 tweets found, 65 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-20%20until%3A2010-06-21include%3Aretweets&src=typd
# 2010-06-20
# 0 tweets found, 65 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-21%20until%3A2010-06-22include%3Aretweets&src=typd
# 2010-06-21
# 2 tweets found, 65 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-22%20until%3A2010-06-23include%3Aretweets&src=typd
# 2010-06-22
# 1 tweets found, 67 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-23%20until%3A2010-06-24include%3Aretweets&src=typd
# 2010-06-23
# 0 tweets found, 68 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-24%20until%3A2010-06-25include%3Aretweets&src=typd
# 2010-06-24
# 1 tweets found, 68 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-25%20until%3A2010-06-26include%3Aretweets&src=typd
# 2010-06-25
# 0 tweets found, 69 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-26%20until%3A2010-06-27include%3Aretweets&src=typd
# 2010-06-26
# 0 tweets found, 69 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-27%20until%3A2010-06-28include%3Aretweets&src=typd
# 2010-06-27
# 0 tweets found, 69 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-28%20until%3A2010-06-29include%3Aretweets&src=typd
# 2010-06-28
# 1 tweets found, 69 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-29%20until%3A2010-06-30include%3Aretweets&src=typd
# 2010-06-29
# 0 tweets found, 70 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-06-30%20until%3A2010-07-01include%3Aretweets&src=typd
# 2010-06-30
# 0 tweets found, 70 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-01%20until%3A2010-07-02include%3Aretweets&src=typd
# 2010-07-01
# 1 tweets found, 70 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-02%20until%3A2010-07-03include%3Aretweets&src=typd
# 2010-07-02
# 2 tweets found, 71 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-03%20until%3A2010-07-04include%3Aretweets&src=typd
# 2010-07-03
# 0 tweets found, 73 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-04%20until%3A2010-07-05include%3Aretweets&src=typd
# 2010-07-04
# 0 tweets found, 73 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-05%20until%3A2010-07-06include%3Aretweets&src=typd
# 2010-07-05
# 0 tweets found, 73 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-06%20until%3A2010-07-07include%3Aretweets&src=typd
# 2010-07-06
# 1 tweets found, 73 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-07%20until%3A2010-07-08include%3Aretweets&src=typd
# 2010-07-07
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-08%20until%3A2010-07-09include%3Aretweets&src=typd
# 2010-07-08
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-09%20until%3A2010-07-10include%3Aretweets&src=typd
# 2010-07-09
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-10%20until%3A2010-07-11include%3Aretweets&src=typd
# 2010-07-10
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-11%20until%3A2010-07-12include%3Aretweets&src=typd
# 2010-07-11
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-12%20until%3A2010-07-13include%3Aretweets&src=typd
# 2010-07-12
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-13%20until%3A2010-07-14include%3Aretweets&src=typd
# 2010-07-13
# 0 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-14%20until%3A2010-07-15include%3Aretweets&src=typd
# 2010-07-14
# 1 tweets found, 74 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-15%20until%3A2010-07-16include%3Aretweets&src=typd
# 2010-07-15
# 0 tweets found, 75 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-16%20until%3A2010-07-17include%3Aretweets&src=typd
# 2010-07-16
# 0 tweets found, 75 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-17%20until%3A2010-07-18include%3Aretweets&src=typd
# 2010-07-17
# 0 tweets found, 75 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-18%20until%3A2010-07-19include%3Aretweets&src=typd
# 2010-07-18
# 0 tweets found, 75 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-19%20until%3A2010-07-20include%3Aretweets&src=typd
# 2010-07-19
# 3 tweets found, 75 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-20%20until%3A2010-07-21include%3Aretweets&src=typd
# 2010-07-20
# 1 tweets found, 78 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-21%20until%3A2010-07-22include%3Aretweets&src=typd
# 2010-07-21
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-22%20until%3A2010-07-23include%3Aretweets&src=typd
# 2010-07-22
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-23%20until%3A2010-07-24include%3Aretweets&src=typd
# 2010-07-23
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-24%20until%3A2010-07-25include%3Aretweets&src=typd
# 2010-07-24
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-25%20until%3A2010-07-26include%3Aretweets&src=typd
# 2010-07-25
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-26%20until%3A2010-07-27include%3Aretweets&src=typd
# 2010-07-26
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-27%20until%3A2010-07-28include%3Aretweets&src=typd
# 2010-07-27
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-28%20until%3A2010-07-29include%3Aretweets&src=typd
# 2010-07-28
# 0 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-29%20until%3A2010-07-30include%3Aretweets&src=typd
# 2010-07-29
# 3 tweets found, 79 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-30%20until%3A2010-07-31include%3Aretweets&src=typd
# 2010-07-30
# 1 tweets found, 82 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-07-31%20until%3A2010-08-01include%3Aretweets&src=typd
# 2010-07-31
# 0 tweets found, 83 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-01%20until%3A2010-08-02include%3Aretweets&src=typd
# 2010-08-01
# 0 tweets found, 83 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-02%20until%3A2010-08-03include%3Aretweets&src=typd
# 2010-08-02
# 0 tweets found, 83 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-03%20until%3A2010-08-04include%3Aretweets&src=typd
# 2010-08-03
# 0 tweets found, 83 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-04%20until%3A2010-08-05include%3Aretweets&src=typd
# 2010-08-04
# 2 tweets found, 83 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-05%20until%3A2010-08-06include%3Aretweets&src=typd
# 2010-08-05
# 0 tweets found, 85 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-06%20until%3A2010-08-07include%3Aretweets&src=typd
# 2010-08-06
# 0 tweets found, 85 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-07%20until%3A2010-08-08include%3Aretweets&src=typd
# 2010-08-07
# 0 tweets found, 85 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-08%20until%3A2010-08-09include%3Aretweets&src=typd
# 2010-08-08
# 0 tweets found, 85 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-09%20until%3A2010-08-10include%3Aretweets&src=typd
# 2010-08-09
# 1 tweets found, 85 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-10%20until%3A2010-08-11include%3Aretweets&src=typd
# 2010-08-10
# 0 tweets found, 86 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-11%20until%3A2010-08-12include%3Aretweets&src=typd
# 2010-08-11
# 0 tweets found, 86 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-12%20until%3A2010-08-13include%3Aretweets&src=typd
# 2010-08-12
# 7 tweets found, 86 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-13%20until%3A2010-08-14include%3Aretweets&src=typd
# 2010-08-13
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-14%20until%3A2010-08-15include%3Aretweets&src=typd
# 2010-08-14
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-15%20until%3A2010-08-16include%3Aretweets&src=typd
# 2010-08-15
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-16%20until%3A2010-08-17include%3Aretweets&src=typd
# 2010-08-16
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-17%20until%3A2010-08-18include%3Aretweets&src=typd
# 2010-08-17
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-18%20until%3A2010-08-19include%3Aretweets&src=typd
# 2010-08-18
# 0 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-19%20until%3A2010-08-20include%3Aretweets&src=typd
# 2010-08-19
# 2 tweets found, 93 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-20%20until%3A2010-08-21include%3Aretweets&src=typd
# 2010-08-20
# 0 tweets found, 95 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-21%20until%3A2010-08-22include%3Aretweets&src=typd
# 2010-08-21
# 0 tweets found, 95 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-22%20until%3A2010-08-23include%3Aretweets&src=typd
# 2010-08-22
# 0 tweets found, 95 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-23%20until%3A2010-08-24include%3Aretweets&src=typd
# 2010-08-23
# 1 tweets found, 95 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-24%20until%3A2010-08-25include%3Aretweets&src=typd
# 2010-08-24
# 1 tweets found, 96 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-25%20until%3A2010-08-26include%3Aretweets&src=typd
# 2010-08-25
# 0 tweets found, 97 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-26%20until%3A2010-08-27include%3Aretweets&src=typd
# 2010-08-26
# 1 tweets found, 97 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-27%20until%3A2010-08-28include%3Aretweets&src=typd
# 2010-08-27
# 0 tweets found, 98 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-28%20until%3A2010-08-29include%3Aretweets&src=typd
# 2010-08-28
# 0 tweets found, 98 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-29%20until%3A2010-08-30include%3Aretweets&src=typd
# 2010-08-29
# 0 tweets found, 98 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-30%20until%3A2010-08-31include%3Aretweets&src=typd
# 2010-08-30
# 1 tweets found, 98 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-08-31%20until%3A2010-09-01include%3Aretweets&src=typd
# 2010-08-31
# 1 tweets found, 99 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-01%20until%3A2010-09-02include%3Aretweets&src=typd
# 2010-09-01
# 1 tweets found, 100 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-02%20until%3A2010-09-03include%3Aretweets&src=typd
# 2010-09-02
# 2 tweets found, 101 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-03%20until%3A2010-09-04include%3Aretweets&src=typd
# 2010-09-03
# 0 tweets found, 103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-04%20until%3A2010-09-05include%3Aretweets&src=typd
# 2010-09-04
# 0 tweets found, 103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-05%20until%3A2010-09-06include%3Aretweets&src=typd
# 2010-09-05
# 0 tweets found, 103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-06%20until%3A2010-09-07include%3Aretweets&src=typd
# 2010-09-06
# 0 tweets found, 103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-07%20until%3A2010-09-08include%3Aretweets&src=typd
# 2010-09-07
# 2 tweets found, 103 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-08%20until%3A2010-09-09include%3Aretweets&src=typd
# 2010-09-08
# 0 tweets found, 105 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-09%20until%3A2010-09-10include%3Aretweets&src=typd
# 2010-09-09
# 1 tweets found, 105 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-10%20until%3A2010-09-11include%3Aretweets&src=typd
# 2010-09-10
# 0 tweets found, 106 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-11%20until%3A2010-09-12include%3Aretweets&src=typd
# 2010-09-11
# 0 tweets found, 106 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-12%20until%3A2010-09-13include%3Aretweets&src=typd
# 2010-09-12
# 0 tweets found, 106 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-13%20until%3A2010-09-14include%3Aretweets&src=typd
# 2010-09-13
# 0 tweets found, 106 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-14%20until%3A2010-09-15include%3Aretweets&src=typd
# 2010-09-14
# 1 tweets found, 106 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-15%20until%3A2010-09-16include%3Aretweets&src=typd
# 2010-09-15
# 1 tweets found, 107 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-16%20until%3A2010-09-17include%3Aretweets&src=typd
# 2010-09-16
# 1 tweets found, 108 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-17%20until%3A2010-09-18include%3Aretweets&src=typd
# 2010-09-17
# 1 tweets found, 109 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-18%20until%3A2010-09-19include%3Aretweets&src=typd
# 2010-09-18
# 0 tweets found, 110 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2010-09-19%20until%3A2010-09-20include%3Aretweets&src=typd
# 2010-09-19
# 0 tweets found, 110 total
# ...
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-03%20until%3A2019-09-04include%3Aretweets&src=typd
# 2019-09-03
# scrolling down to load more tweets
# 11 tweets found, 39000 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-04%20until%3A2019-09-05include%3Aretweets&src=typd
# 2019-09-04
# scrolling down to load more tweets
# 16 tweets found, 39011 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-05%20until%3A2019-09-06include%3Aretweets&src=typd
# 2019-09-05
# scrolling down to load more tweets
# 19 tweets found, 39027 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-06%20until%3A2019-09-07include%3Aretweets&src=typd
# 2019-09-06
# scrolling down to load more tweets
# scrolling down to load more tweets
# 23 tweets found, 39046 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-07%20until%3A2019-09-08include%3Aretweets&src=typd
# 2019-09-07
# scrolling down to load more tweets
# 18 tweets found, 39069 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-08%20until%3A2019-09-09include%3Aretweets&src=typd
# 2019-09-08
# 5 tweets found, 39087 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-09%20until%3A2019-09-10include%3Aretweets&src=typd
# 2019-09-09
# scrolling down to load more tweets
# scrolling down to load more tweets
# 27 tweets found, 39092 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-10%20until%3A2019-09-11include%3Aretweets&src=typd
# 2019-09-10
# scrolling down to load more tweets
# 12 tweets found, 39119 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-11%20until%3A2019-09-12include%3Aretweets&src=typd
# 2019-09-11
# scrolling down to load more tweets
# scrolling down to load more tweets
# 23 tweets found, 39131 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-12%20until%3A2019-09-13include%3Aretweets&src=typd
# 2019-09-12
# scrolling down to load more tweets
# 13 tweets found, 39154 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-13%20until%3A2019-09-14include%3Aretweets&src=typd
# 2019-09-13
# 9 tweets found, 39167 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-14%20until%3A2019-09-15include%3Aretweets&src=typd
# 2019-09-14
# scrolling down to load more tweets
# 13 tweets found, 39176 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-15%20until%3A2019-09-16include%3Aretweets&src=typd
# 2019-09-15
# scrolling down to load more tweets
# 15 tweets found, 39189 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-16%20until%3A2019-09-17include%3Aretweets&src=typd
# 2019-09-16
# scrolling down to load more tweets
# scrolling down to load more tweets
# 25 tweets found, 39204 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-17%20until%3A2019-09-18include%3Aretweets&src=typd
# 2019-09-17
# 9 tweets found, 39229 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-18%20until%3A2019-09-19include%3Aretweets&src=typd
# 2019-09-18
# scrolling down to load more tweets
# 17 tweets found, 39238 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-19%20until%3A2019-09-20include%3Aretweets&src=typd
# 2019-09-19
# 7 tweets found, 39255 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-20%20until%3A2019-09-21include%3Aretweets&src=typd
# 2019-09-20
# 9 tweets found, 39262 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-21%20until%3A2019-09-22include%3Aretweets&src=typd
# 2019-09-21
# scrolling down to load more tweets
# 16 tweets found, 39271 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-22%20until%3A2019-09-23include%3Aretweets&src=typd
# 2019-09-22
# scrolling down to load more tweets
# 16 tweets found, 39287 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-23%20until%3A2019-09-24include%3Aretweets&src=typd
# 2019-09-23
# scrolling down to load more tweets
# 11 tweets found, 39303 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-24%20until%3A2019-09-25include%3Aretweets&src=typd
# 2019-09-24
# scrolling down to load more tweets
# 14 tweets found, 39314 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-25%20until%3A2019-09-26include%3Aretweets&src=typd
# 2019-09-25
# scrolling down to load more tweets
# scrolling down to load more tweets
# 23 tweets found, 39328 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-26%20until%3A2019-09-27include%3Aretweets&src=typd
# 2019-09-26
# scrolling down to load more tweets
# 17 tweets found, 39351 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-27%20until%3A2019-09-28include%3Aretweets&src=typd
# 2019-09-27
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39368 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-28%20until%3A2019-09-29include%3Aretweets&src=typd
# 2019-09-28
# scrolling down to load more tweets
# 13 tweets found, 39388 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-29%20until%3A2019-09-30include%3Aretweets&src=typd
# 2019-09-29
# scrolling down to load more tweets
# 16 tweets found, 39401 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-09-30%20until%3A2019-10-01include%3Aretweets&src=typd
# 2019-09-30
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 32 tweets found, 39417 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-01%20until%3A2019-10-02include%3Aretweets&src=typd
# 2019-10-01
# scrolling down to load more tweets
# 15 tweets found, 39449 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-02%20until%3A2019-10-03include%3Aretweets&src=typd
# 2019-10-02
# scrolling down to load more tweets
# 19 tweets found, 39464 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-03%20until%3A2019-10-04include%3Aretweets&src=typd
# 2019-10-03
# scrolling down to load more tweets
# scrolling down to load more tweets
# 25 tweets found, 39483 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-04%20until%3A2019-10-05include%3Aretweets&src=typd
# 2019-10-04
# scrolling down to load more tweets
# scrolling down to load more tweets
# 29 tweets found, 39508 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-05%20until%3A2019-10-06include%3Aretweets&src=typd
# 2019-10-05
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 30 tweets found, 39537 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-06%20until%3A2019-10-07include%3Aretweets&src=typd
# 2019-10-06
# scrolling down to load more tweets
# scrolling down to load more tweets
# 25 tweets found, 39567 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-07%20until%3A2019-10-08include%3Aretweets&src=typd
# 2019-10-07
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39592 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-08%20until%3A2019-10-09include%3Aretweets&src=typd
# 2019-10-08
# scrolling down to load more tweets
# scrolling down to load more tweets
# 22 tweets found, 39612 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-09%20until%3A2019-10-10include%3Aretweets&src=typd
# 2019-10-09
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 35 tweets found, 39634 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-10%20until%3A2019-10-11include%3Aretweets&src=typd
# 2019-10-10
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39669 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-11%20until%3A2019-10-12include%3Aretweets&src=typd
# 2019-10-11
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39689 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-12%20until%3A2019-10-13include%3Aretweets&src=typd
# 2019-10-12
# scrolling down to load more tweets
# 18 tweets found, 39709 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-13%20until%3A2019-10-14include%3Aretweets&src=typd
# 2019-10-13
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39727 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-14%20until%3A2019-10-15include%3Aretweets&src=typd
# 2019-10-14
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 31 tweets found, 39747 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-15%20until%3A2019-10-16include%3Aretweets&src=typd
# 2019-10-15
# scrolling down to load more tweets
# 14 tweets found, 39778 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-16%20until%3A2019-10-17include%3Aretweets&src=typd
# 2019-10-16
# scrolling down to load more tweets
# 19 tweets found, 39792 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-17%20until%3A2019-10-18include%3Aretweets&src=typd
# 2019-10-17
# scrolling down to load more tweets
# 18 tweets found, 39811 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-18%20until%3A2019-10-19include%3Aretweets&src=typd
# 2019-10-18
# scrolling down to load more tweets
# 17 tweets found, 39829 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-19%20until%3A2019-10-20include%3Aretweets&src=typd
# 2019-10-19
# scrolling down to load more tweets
# scrolling down to load more tweets
# 20 tweets found, 39846 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-20%20until%3A2019-10-21include%3Aretweets&src=typd
# 2019-10-20
# scrolling down to load more tweets
# 16 tweets found, 39866 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-21%20until%3A2019-10-22include%3Aretweets&src=typd
# 2019-10-21
# scrolling down to load more tweets
# 11 tweets found, 39882 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-22%20until%3A2019-10-23include%3Aretweets&src=typd
# 2019-10-22
# scrolling down to load more tweets
# 14 tweets found, 39893 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-23%20until%3A2019-10-24include%3Aretweets&src=typd
# 2019-10-23
# scrolling down to load more tweets
# scrolling down to load more tweets
# 21 tweets found, 39907 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-24%20until%3A2019-10-25include%3Aretweets&src=typd
# 2019-10-24
# 8 tweets found, 39928 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-25%20until%3A2019-10-26include%3Aretweets&src=typd
# 2019-10-25
# scrolling down to load more tweets
# 18 tweets found, 39936 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-26%20until%3A2019-10-27include%3Aretweets&src=typd
# 2019-10-26
# scrolling down to load more tweets
# scrolling down to load more tweets
# 24 tweets found, 39954 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-27%20until%3A2019-10-28include%3Aretweets&src=typd
# 2019-10-27
# 5 tweets found, 39978 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-28%20until%3A2019-10-29include%3Aretweets&src=typd
# 2019-10-28
# 6 tweets found, 39983 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-29%20until%3A2019-10-30include%3Aretweets&src=typd
# 2019-10-29
# scrolling down to load more tweets
# 17 tweets found, 39989 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-30%20until%3A2019-10-31include%3Aretweets&src=typd
# 2019-10-30
# scrolling down to load more tweets
# 19 tweets found, 40006 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-10-31%20until%3A2019-11-01include%3Aretweets&src=typd
# 2019-10-31
# scrolling down to load more tweets
# 17 tweets found, 40025 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-01%20until%3A2019-11-02include%3Aretweets&src=typd
# 2019-11-01
# scrolling down to load more tweets
# scrolling down to load more tweets
# 28 tweets found, 40042 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-02%20until%3A2019-11-03include%3Aretweets&src=typd
# 2019-11-02
# 8 tweets found, 40070 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-03%20until%3A2019-11-04include%3Aretweets&src=typd
# 2019-11-03
# scrolling down to load more tweets
# 19 tweets found, 40078 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-04%20until%3A2019-11-05include%3Aretweets&src=typd
# 2019-11-04
# scrolling down to load more tweets
# scrolling down to load more tweets
# 22 tweets found, 40097 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-05%20until%3A2019-11-06include%3Aretweets&src=typd
# 2019-11-05
# scrolling down to load more tweets
# 14 tweets found, 40119 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-06%20until%3A2019-11-07include%3Aretweets&src=typd
# 2019-11-06
# scrolling down to load more tweets
# 16 tweets found, 40133 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-07%20until%3A2019-11-08include%3Aretweets&src=typd
# 2019-11-07
# scrolling down to load more tweets
# 16 tweets found, 40149 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-08%20until%3A2019-11-09include%3Aretweets&src=typd
# 2019-11-08
# 3 tweets found, 40165 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-09%20until%3A2019-11-10include%3Aretweets&src=typd
# 2019-11-09
# scrolling down to load more tweets
# 12 tweets found, 40168 total
# https://twitter.com/search?f=tweets&vertical=default&q=from%3Arealdonaldtrump%20since%3A2019-11-10%20until%3A2019-11-11include%3Aretweets&src=typd
# 2019-11-10
# scrolling down to load more tweets
# 14 tweets found, 40180 total
# tweets found on this scrape:  40194
# total tweet count:  40198
# all done here

# %%
output_file_short = 'realdonaldtrump_short.json'
user = 'trumptwits'
with open(output_file_short) as master_file:
    data = json.load(master_file)
with open('{}.csv'.format(user), 'w') as write_file:
    fields = ["text", "time"]
    print('creating CSV version of minimized json master file')    
    f = csv.writer(write_file)
    f.writerow(fields)
    for x in data:
        f.writerow([x["text"].encode('unicode_escape'), x["created_at"]])
    print("Done")
