# %%
from project_helper import TweetData, IntradayData, FuturesCloseData
import pandas as pd
import numpy as np
from pytz import timezone
import datetime
from datetime import timedelta  
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Intraday S&P500 futures feature

# %%
tweet_data = TweetData()
tweet_data.raw_tweets.head()
# Out:
#                                                                       tweets
# timestamp
# 2019-11-17 19:57:12-06:00  "Tell Jennifer Williams whoever that is to rea...
# 2019-11-17 19:56:02-06:00                           "https://t.co/I3lO117SVh
# 2019-11-17 19:49:47-06:00  "Paul Krugman of @nytimes has been wrong about...
# 2019-11-17 19:47:32-06:00  "Schiff is a Corrupt Politician! https://t.co/...
# 2019-11-17 19:30:09-06:00  ".@SteveScalise blew the nasty &amp; obnoxious...

# %%
md = IntradayData()
fin_data = md.get_data()

# %%
# Number of tweets with exactly the same timestamp
len(tweet_data.raw_tweets.index) - len(set(tweet_data.raw_tweets.index))
# Out:
# 321

# %%
print(fin_data.shape)
fin_data.head()
# Out:
# (1040156, 2)
#                               Open    Close
# timestamp
# 2016-11-13 17:01:00-06:00  2183.00  2183.25
# 2016-11-13 17:02:00-06:00  2183.25  2182.00
# 2016-11-13 17:03:00-06:00  2182.00  2182.75
# 2016-11-13 17:04:00-06:00  2182.50  2182.50
# 2016-11-13 17:05:00-06:00  2182.75  2183.00

# %%
subset = (tweet_data.raw_tweets.index > fin_data.index[0]) & (tweet_data.raw_tweets.index < fin_data.index[-1])
sub_data = tweet_data.raw_tweets[subset]

# %%
sub_data.head()
# Out:
#                                                                       tweets
# timestamp
# 2019-11-08 03:08:53-06:00                           "https://t.co/z0I7wBsgTP
# 2019-11-08 00:08:15-06:00  "STATEMENT FROM PRESIDENT DONALD J. TRUMP http...
# 2019-11-07 15:43:29-06:00   "Stock Market up big today. A New Record. Enjoy!
# 2019-11-07 15:41:53-06:00  "The Radical Left Dems and LameStream Media ar...
# 2019-11-07 15:27:57-06:00  "The Amazon Washington Post and three lowlife ...

# %%
ts_pre = [ time + datetime.timedelta(seconds = - time.second) for i, time in enumerate(sub_data.index)]
ts_post = [ time + datetime.timedelta(seconds = 60*1 - time.second) for i, time in enumerate(sub_data.index)]
ts_1min = [ time + datetime.timedelta(seconds = 60*2 - time.second) for i, time in enumerate(sub_data.index)]
ts_5min = [ time + datetime.timedelta(seconds = 60*6 - time.second) for i, time in enumerate(sub_data.index)]
ts_15min = [ time + datetime.timedelta(seconds = 60*16 - time.second) for i, time in enumerate(sub_data.index)]

# %%
min_dict = {}
for i, ts in enumerate(ts_post):
    try:
        min_dict[ts] = min_dict[ts] + sub_data.tweets.iloc[i]
    except KeyError:
        min_dict[ts] = sub_data.tweets.iloc[i]
        
data_min = pd.DataFrame(data = min_dict.values(), index = min_dict.keys())
data_min.columns = ['tweets']
data_min.index.name = 'timestamp'
data_min.head()
# Out:
#                                                                       tweets
# timestamp
# 2019-11-08 03:09:00-06:00                           "https://t.co/z0I7wBsgTP
# 2019-11-08 00:09:00-06:00  "STATEMENT FROM PRESIDENT DONALD J. TRUMP http...
# 2019-11-07 15:44:00-06:00   "Stock Market up big today. A New Record. Enjoy!
# 2019-11-07 15:42:00-06:00  "The Radical Left Dems and LameStream Media ar...
# 2019-11-07 15:28:00-06:00  "The Amazon Washington Post and three lowlife ...

# %%
ts_dict = {a:b for a, b in zip(ts_post, sub_data.index)}

# %%
for ret, ts in zip(['ret_1', 'ret_5', 'ret_15'],[ts_1min,ts_5min,ts_15min] ):
    imp_open = fin_data.loc[ts_post]['Open']
    imp_close = fin_data.loc[ts]['Close']
    hl = (imp_open - imp_close.values)/imp_open
    hl = hl.loc[~hl.index.duplicated(keep='first')]
    data_min[ret] = hl.values
    
data_min = data_min.dropna()

# %%
data_min.head()
# Out:
#                                                                       tweets  \
# timestamp
# 2019-11-08 03:09:00-06:00                           "https://t.co/z0I7wBsgTP
# 2019-11-08 00:09:00-06:00  "STATEMENT FROM PRESIDENT DONALD J. TRUMP http...
# 2019-11-07 15:44:00-06:00   "Stock Market up big today. A New Record. Enjoy!
# 2019-11-07 15:42:00-06:00  "The Radical Left Dems and LameStream Media ar...
# 2019-11-07 14:52:00-06:00  "ÒWhat did Hunter Biden do for the money?Ó @Se...
#
#                               ret_1     ret_5    ret_15
# timestamp
# 2019-11-08 03:09:00-06:00  0.000162  0.000406  0.000406
# 2019-11-08 00:09:00-06:00  0.000162  0.000244  0.000244
# 2019-11-07 15:44:00-06:00 -0.000081  0.000000  0.000000
# 2019-11-07 15:42:00-06:00  0.000000  0.000000  0.000000
# 2019-11-07 14:52:00-06:00  0.000730  0.000730 -0.000081

# %%
after_4_tweets = data_min.index.hour >= 15
data_min['after4_date'] = data_min.index
data_min.after4_date[after_4_tweets] +=  timedelta(days=1)
data_min.after4_date =data_min.after4_date.dt.date
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
mini = data_min.groupby('after4_date').min()
maxi = data_min.groupby('after4_date').max()
features = pd.DataFrame(index = mini.index, columns=['intra_ret_1', 'intra_ret_5', 'intra_ret_15'] )

# %%
for ind in mini.index: 
    for ret in ['ret_1', 'ret_5', 'ret_15']:
        if abs(mini[ret].loc[ind]) > abs(maxi[ret].loc[ind]):
            features['intra_' + ret].loc[ind] = mini[ret].loc[ind]
        else:
            features['intra_' + ret].loc[ind] = maxi[ret].loc[ind]

# %%
features.index.name = 'timestamp'
features['intra_blend'] = features.mean(axis=1)
features['intra_blend'].to_csv('features/intraday.csv')

# %%
features.loc[datetime.date(2019, 8, 24)]
# Out:
# intra_ret_1    -0.00325332
# intra_ret_5    -0.00633078
# intra_ret_15   -0.00527565
# intra_blend    -0.00495325
# Name: 2019-08-24, dtype: object

# %%
data_min.tail()
# Out:
#                                                                       tweets  \
# timestamp
# 2016-11-16 11:29:00-06:00  "I am not trying to get ""top level security c...
# 2016-11-16 02:56:00-06:00  "Very organized process taking place as I deci...
# 2016-11-15 13:41:00-06:00  "The Electoral College is actually genius in t...
# 2016-11-15 13:35:00-06:00  "If the election were based on total popular v...
# 2016-11-13 18:47:00-06:00  "The debates especially the second and third p...
#
#                               ret_1     ret_5    ret_15 after4_date
# timestamp
# 2016-11-16 11:29:00-06:00 -0.000114 -0.000571 -0.000114  2016-11-16
# 2016-11-16 02:56:00-06:00  0.000228  0.000683  0.000455  2016-11-16
# 2016-11-15 13:41:00-06:00  0.000000 -0.000456 -0.001141  2016-11-15
# 2016-11-15 13:35:00-06:00 -0.000114 -0.000571 -0.000685  2016-11-15
# 2016-11-13 18:47:00-06:00 -0.000114 -0.000343 -0.000685  2016-11-14

# %%
data_min_sort = data_min.dropna().sort_values(by = 'ret_5')
print(data_min_sort.shape)
data_min_sort.head()
# Out:
# (5923, 5)
#                                                                       tweets  \
# timestamp
# 2019-08-23 14:58:00-05:00  "As usual the Fed did NOTHING! It is incredibl...
# 2019-08-23 15:00:00-05:00  "....all deliveries of Fentanyl from China (or...
# 2018-12-07 11:54:00-06:00  "....Foundation be listed at the top of the Re...
# 2018-12-21 14:42:00-06:00  "There has never been a president who has been...
# 2018-12-19 14:45:00-06:00  "The Trump Foundation has done great work and ...
#
#                               ret_1     ret_5    ret_15 after4_date
# timestamp
# 2019-08-23 14:58:00-05:00 -0.001938 -0.007930 -0.006696  2019-08-23
# 2019-08-23 15:00:00-05:00 -0.003253 -0.006331 -0.005276  2019-08-24
# 2018-12-07 11:54:00-06:00 -0.002064 -0.003846 -0.002626  2018-12-07
# 2018-12-21 14:42:00-06:00 -0.001752 -0.003608 -0.002165  2018-12-21
# 2018-12-19 14:45:00-06:00 -0.001790 -0.003580 -0.001690  2018-12-19

# %%
data_min_sort.to_csv('results/sorted_trump.csv')

# %%
tweet_data.clean_tweets
# Out:
#                                                                       tweets  \
# timestamp
# 2019-11-17 19:57:12-06:00  tell jennifer williams whoever that is to read...
# 2019-11-17 19:56:02-06:00
# 2019-11-17 19:49:47-06:00  paul krugman of has been wrong about me from t...
# 2019-11-17 19:47:32-06:00                    schiff is a corrupt politician
# 2019-11-17 19:30:09-06:00  blew the nasty amp obnoxious chris wallace wil...
# 2019-11-17 19:26:04-06:00  blew the nasty amp obnoxious chris wallace wil...
# 2019-11-17 18:34:46-06:00                                       thanks eric
# 2019-11-17 18:10:59-06:00
# 2019-11-17 18:10:19-06:00
# 2019-11-17 17:54:12-06:00
# 2019-11-17 17:43:27-06:00  paul krugman has called me wrong from day one ...
# 2019-11-17 17:33:01-06:00
# 2019-11-17 17:29:58-06:00
# 2019-11-17 17:26:49-06:00
# 2019-11-17 17:26:10-06:00
# 2019-11-17 17:12:14-06:00        i agree katrina pam bondi is a great woman
# 2019-11-17 16:56:41-06:00  the do nothing dems are now doing even less an...
# 2019-11-17 16:51:39-06:00  joe ricketts one of our country s most success...
# 2019-11-17 16:38:34-06:00                                  a big difference
# 2019-11-17 16:08:11-06:00  our great farmers will recieve another major r...
# 2019-11-17 15:02:08-06:00  has a great show going on right now a m fantas...
# 2019-11-17 14:58:09-06:00  mr chairman joe biden may be sleepy and very s...
# %%
futs[futs.name == 'CME Euro FX Futures #1 (EC1) - Front Month - Unadjusted Prices, Roll on Open Interest Switch'].head()
# Out:
#        quandl_code                                               name  \
# 31996   CME_EC1_ON  CME Euro FX Futures #1 (EC1) - Front Month - U...
# 134844  CME_EC1_ON  CME Euro FX Futures #1 (EC1) - Front Month - U...
# 344786  CME_EC1_ON  CME Euro FX Futures #1 (EC1) - Front Month - U...
# 650755  CME_EC1_ON  CME Euro FX Futures #1 (EC1) - Front Month - U...
# 669085  CME_EC1_ON  CME Euro FX Futures #1 (EC1) - Front Month - U...
#
#        exchange symbol  depth method        date     open     high      low  \
# 31996       CME     EC      1     ON  2018-06-18  1.16760  1.17050  1.16445
# 134844      CME     EC      1     ON  2018-06-19  1.17005  1.17240  1.16095
# 344786      CME     EC      1     ON  2018-06-20  1.16640  1.16765  1.16130
# 650755      CME     EC      1     ON  2018-06-21  1.16485  1.17085  1.15820
# 669085      CME     EC      1     ON  2018-06-22  1.16800  1.17495  1.16745
#
#          settle  volume  prev_day_open_interest front_contract
# 31996   1.16955  181774                  461883        ECU2018
# 134844  1.16530  294547                  460251        ECU2018
# 344786  1.16630  228246                  464777        ECU2018
# 650755  1.16980  325658                  469309        ECU2018
# 669085  1.17375  233222                  474422        ECU2018

# %%
sorted(futs[futs.name == 'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch'].date)
# Out:
# ['2014-01-02',
#  '2014-01-03',
#  '2014-01-06',
#  '2014-01-07',
#  '2014-01-08',
#  '2014-01-09',
#  '2014-01-10',
#  '2014-01-13',
#  '2014-01-14',
#  '2014-01-15',
#  '2014-01-16',
#  '2014-01-17',
#  '2014-01-21',
#  '2014-01-22',
#  '2014-01-23',
#  '2014-01-24',
#  '2014-01-27',
#  '2014-01-28',
#  '2014-01-29',
#  '2014-01-30',
#  '2014-01-31',
#  '2014-02-03',
#  '2014-02-04',
#  '2014-02-05',
#  '2014-02-06',
#  '2014-02-07',
#  '2014-02-10',
#  '2014-02-11',
#  '2014-02-12',
#  '2014-02-13',
#  '2014-02-14',
#  '2014-02-18',
#  '2014-02-19',
#  '2014-02-20',
#  '2014-02-21',
#  '2014-02-24',
#  '2014-02-25',
#  '2014-02-26',
#  '2014-02-27',
#  '2014-02-28',
#  '2014-03-03',
#  '2014-03-04',
#  '2014-03-05',
#  '2014-03-06',
#  '2014-03-07',
#  '2014-03-10',
#  '2014-03-11',
#  '2014-03-12',
#  '2014-03-13',
#  '2014-03-14',
#  '2014-03-17',
#  '2014-03-18',
#  '2014-03-19',
#  '2014-03-20',
#  '2014-03-21',
#  '2014-03-24',
#  '2014-03-25',
#  '2014-03-26',
#  '2014-03-27',
#  '2014-03-28',
#  '2014-03-31',
#  '2014-04-01',
#  '2014-04-02',
#  '2014-04-03',
#  '2014-04-04',
#  '2014-04-07',
#  '2014-04-08',
#  '2014-04-09',
#  '2014-04-10',
#  '2014-04-11',
#  '2014-04-14',
#  '2014-04-15',
#  '2014-04-16',
#  '2014-04-17',
#  '2014-04-21',
#  '2014-04-22',
#  '2014-04-23',
#  '2014-04-24',
#  '2014-04-25',
#  '2014-04-28',
#  '2014-04-29',
#  '2014-04-30',
#  '2014-05-01',
#  '2014-05-02',
#  '2014-05-05',
#  '2014-05-06',
#  '2014-05-07',
#  '2014-05-08',
#  '2014-05-09',
#  '2014-05-12',
#  '2014-05-13',
#  '2014-05-14',
#  '2014-05-15',
#  '2014-05-16',
#  '2014-05-19',
#  '2014-05-20',
#  '2014-05-21',
#  '2014-05-22',
#  '2014-05-23',
#  '2014-05-27',
#  '2014-05-28',
#  '2014-05-29',
#  '2014-05-30',
#  '2014-06-02',
#  '2014-06-03',
#  '2014-06-04',
#  '2014-06-05',
#  '2014-06-06',
#  '2014-06-09',
#  '2014-06-10',
#  '2014-06-11',
#  '2014-06-12',
#  '2014-06-13',
#  '2014-06-16',
#  '2014-06-17',
#  '2014-06-18',
#  '2014-06-19',
#  '2014-06-20',
#  '2014-06-23',
#  '2014-06-24',
#  '2014-06-25',
#  '2014-06-26',
#  '2014-06-27',
#  '2014-06-30',
#  '2014-07-01',
#  '2014-07-02',
#  '2014-07-03',
#  '2014-07-07',
#  '2014-07-08',
#  '2014-07-09',
#  '2014-07-10',
#  '2014-07-11',
#  '2014-07-14',
#  '2014-07-15',
#  '2014-07-16',
#  '2014-07-17',
#  '2014-07-18',
#  '2014-07-21',
#  '2014-07-22',
#  '2014-07-23',
#  '2014-07-24',
#  '2014-07-25',
#  '2014-07-28',
#  '2014-07-29',
#  '2014-07-30',
#  '2014-07-31',
#  '2014-08-01',
#  '2014-08-04',
#  '2014-08-05',
#  '2014-08-06',
#  '2014-08-07',
#  '2014-08-08',
#  '2014-08-11',
#  '2014-08-12',
#  '2014-08-13',
#  '2014-08-14',
#  '2014-08-15',
#  '2014-08-18',
#  '2014-08-19',
#  '2014-08-20',
#  '2014-08-21',
#  '2014-08-22',
#  '2014-08-25',
#  '2014-08-26',
#  '2014-08-27',
#  '2014-08-28',
#  '2014-08-29',
#  '2014-09-02',
#  '2014-09-03',
#  '2014-09-04',
#  '2014-09-05',
#  '2014-09-08',
#  '2014-09-09',
#  '2014-09-10',
#  '2014-09-11',
#  '2014-09-12',
#  '2014-09-15',
#  '2014-09-16',
#  '2014-09-17',
#  '2014-09-18',
#  '2014-09-19',
#  '2014-09-22',
#  '2014-09-23',
#  '2014-09-24',
#  '2014-09-25',
#  '2014-09-26',
#  '2014-09-29',
#  '2014-09-30',
#  '2014-10-01',
#  '2014-10-02',
#  '2014-10-03',
#  '2014-10-06',
#  '2014-10-07',
#  '2014-10-08',
#  '2014-10-09',
#  '2014-10-10',
#  '2014-10-13',
#  '2014-10-14',
#  '2014-10-15',
#  '2014-10-16',
#  '2014-10-17',
#  '2014-10-20',
#  '2014-10-21',
#  '2014-10-22',
#  '2014-10-23',
#  '2014-10-24',
#  '2014-10-27',
#  '2014-10-28',
#  '2014-10-29',
#  '2014-10-30',
#  '2014-10-31',
#  '2014-11-03',
#  '2014-11-04',
#  '2014-11-05',
#  '2014-11-06',
#  '2014-11-07',
#  '2014-11-10',
#  '2014-11-11',
#  '2014-11-12',
#  '2014-11-13',
#  '2014-11-14',
#  '2014-11-17',
#  '2014-11-18',
#  '2014-11-19',
#  '2014-11-20',
#  '2014-11-21',
#  '2014-11-24',
#  '2014-11-25',
#  '2014-11-26',
#  '2014-11-28',
#  '2014-12-01',
#  '2014-12-02',
#  '2014-12-03',
#  '2014-12-04',
#  '2014-12-05',
#  '2014-12-08',
#  '2014-12-09',
#  '2014-12-10',
#  '2014-12-11',
#  '2014-12-12',
#  '2014-12-15',
#  '2014-12-16',
#  '2014-12-17',
#  '2014-12-18',
#  '2014-12-19',
#  '2014-12-22',
#  '2014-12-23',
#  '2014-12-24',
#  '2014-12-26',
#  '2014-12-29',
#  '2014-12-30',
#  '2014-12-31',
#  '2015-01-02',
#  '2015-01-05',
#  '2015-01-06',
#  '2015-01-07',
#  '2015-01-08',
#  '2015-01-09',
#  '2015-01-12',
#  '2015-01-13',
#  '2015-01-14',
#  '2015-01-15',
#  '2015-01-16',
#  '2015-01-20',
#  '2015-01-21',
#  '2015-01-22',
#  '2015-01-23',
#  '2015-01-26',
#  '2015-01-27',
#  '2015-01-28',
#  '2015-01-29',
#  '2015-01-30',
#  '2015-02-02',
#  '2015-02-03',
#  '2015-02-04',
#  '2015-02-05',
#  '2015-02-06',
#  '2015-02-09',
#  '2015-02-10',
#  '2015-02-11',
#  '2015-02-12',
#  '2015-02-13',
#  '2015-02-17',
#  '2015-02-18',
#  '2015-02-19',
#  '2015-02-20',
#  '2015-02-23',
#  '2015-02-24',
#  '2015-02-25',
#  '2015-02-26',
#  '2015-02-27',
#  '2015-03-02',
#  '2015-03-03',
#  '2015-03-04',
#  '2015-03-05',
#  '2015-03-06',
#  '2015-03-09',
#  '2015-03-10',
#  '2015-03-11',
#  '2015-03-12',
#  '2015-03-13',
#  '2015-03-16',
#  '2015-03-17',
#  '2015-03-18',
#  '2015-03-19',
#  '2015-03-20',
#  '2015-03-23',
#  '2015-03-24',
#  '2015-03-25',
#  '2015-03-26',
#  '2015-03-27',
#  '2015-03-30',
#  '2015-03-31',
#  '2015-04-01',
#  '2015-04-02',
#  '2015-04-06',
#  '2015-04-07',
#  '2015-04-08',
#  '2015-04-09',
#  '2015-04-10',
#  '2015-04-13',
#  '2015-04-14',
#  '2015-04-15',
#  '2015-04-16',
#  '2015-04-17',
#  '2015-04-20',
#  '2015-04-21',
#  '2015-04-22',
#  '2015-04-23',
#  '2015-04-24',
#  '2015-04-27',
#  '2015-04-28',
#  '2015-04-29',
#  '2015-04-30',
#  '2015-05-01',
#  '2015-05-04',
#  '2015-05-05',
#  '2015-05-06',
#  '2015-05-07',
#  '2015-05-08',
#  '2015-05-11',
#  '2015-05-12',
#  '2015-05-13',
#  '2015-11-25',
#  '2015-11-27',
#  '2015-11-30',
#  '2015-12-01',
#  '2015-12-02',
#  '2015-12-03',
#  '2015-12-04',
#  '2015-12-07',
#  '2015-12-08',
#  '2015-12-09',
#  '2015-12-10',
#  '2015-12-11',
#  '2015-12-14',
#  '2015-12-15',
#  '2015-12-16',
#  '2015-12-17',
#  '2015-12-18',
#  '2015-12-21',
#  '2015-12-22',
#  '2015-12-23',
#  '2015-12-24',
#  '2015-12-28',
#  '2015-12-29',
#  '2015-12-30',
#  '2015-12-31',
#  '2016-01-04',
#  '2016-01-05',
#  '2016-01-06',
#  '2016-01-07',
#  '2016-01-08',
#  '2016-01-11',
#  '2016-01-12',
#  '2016-01-13',
#  '2016-01-14',
#  '2016-01-15',
#  '2016-01-19',
#  '2016-01-20',
#  '2016-01-21',
#  '2016-01-22',
#  '2016-01-25',
#  '2016-01-26',
#  '2016-01-27',
#  '2016-01-28',
#  '2016-01-29',
#  '2016-02-01',
#  '2016-02-02',
#  '2016-02-03',
#  '2016-02-04',
#  '2016-02-05',
#  '2016-02-08',
#  '2016-02-09',
#  '2016-02-10',
#  '2016-02-11',
#  '2016-02-12',
#  '2016-02-16',
#  '2016-02-17',
#  '2016-02-18',
#  '2016-02-19',
#  '2016-02-22',
#  '2016-02-23',
#  '2016-02-24',
#  '2016-02-25',
#  '2016-02-26',
#  '2016-02-29',
#  '2016-03-01',
#  '2016-03-02',
#  '2016-03-03',
#  '2016-03-04',
#  '2016-03-07',
#  '2016-03-08',
#  '2016-03-09',
#  '2016-03-10',
#  '2016-03-11',
#  '2016-03-14',
#  '2016-03-15',
#  '2016-03-16',
#  '2016-03-17',
#  '2016-03-18',
#  '2016-03-21',
#  '2016-03-22',
#  '2016-03-23',
#  '2016-03-24',
#  '2016-03-28',
#  '2016-03-29',
#  '2016-03-30',
#  '2016-03-31',
#  '2016-04-01',
#  '2016-04-04',
#  '2016-04-05',
#  '2016-04-06',
#  '2016-04-07',
#  '2016-04-08',
#  '2016-04-11',
#  '2016-04-12',
#  '2016-04-13',
#  '2016-04-14',
#  '2016-04-15',
#  '2016-04-18',
#  '2016-04-19',
#  '2016-04-20',
#  '2016-04-21',
#  '2016-04-22',
#  '2016-04-25',
#  '2016-04-26',
#  '2016-04-27',
#  '2016-04-28',
#  '2016-04-29',
#  '2016-05-02',
#  '2016-05-03',
#  '2016-05-04',
#  '2016-05-05',
#  '2016-05-06',
#  '2016-05-09',
#  '2016-05-10',
#  '2016-05-11',
#  '2016-05-12',
#  '2016-05-13',
#  '2016-05-16',
#  '2016-05-17',
#  '2016-05-18',
#  '2016-05-19',
#  '2016-05-20',
#  '2016-05-23',
#  '2016-05-24',
#  '2016-05-25',
#  '2016-05-26',
#  '2016-05-27',
#  '2016-05-31',
#  '2016-06-01',
#  '2016-06-02',
#  '2016-06-03',
#  '2016-06-06',
#  '2016-06-07',
#  '2016-06-08',
#  '2016-06-09',
#  '2016-06-10',
#  '2016-06-13',
#  '2016-06-14',
#  '2016-06-15',
#  '2016-06-16',
#  '2016-06-17',
#  '2016-06-20',
#  '2016-06-21',
#  '2016-06-22',
#  '2016-06-23',
#  '2016-06-24',
#  '2016-06-27',
#  '2016-06-28',
#  '2016-06-29',
#  '2016-06-30',
#  '2016-07-01',
#  '2016-07-05',
#  '2016-07-06',
#  '2016-07-07',
#  '2016-07-08',
#  '2016-07-11',
#  '2016-07-12',
#  '2016-07-13',
#  '2016-07-14',
#  '2016-07-15',
#  '2016-07-18',
#  '2016-07-19',
#  '2016-07-20',
#  '2016-07-21',
#  '2016-07-22',
#  '2016-07-25',
#  '2016-07-26',
#  '2016-07-27',
#  '2016-07-28',
#  '2016-07-29',
#  '2016-08-01',
#  '2016-08-02',
#  '2016-08-03',
#  '2016-08-04',
#  '2016-08-05',
#  '2016-08-08',
#  '2016-08-09',
#  '2016-08-10',
#  '2016-08-11',
#  '2016-08-12',
#  '2016-08-15',
#  '2016-08-16',
#  '2016-08-17',
#  '2016-08-18',
#  '2016-08-19',
#  '2016-08-22',
#  '2016-08-23',
#  '2016-08-24',
#  '2016-08-25',
#  '2016-08-26',
#  '2016-08-29',
#  '2016-08-30',
#  '2016-08-31',
#  '2016-09-01',
#  '2016-09-02',
#  '2016-09-06',
#  '2016-09-07',
#  '2016-09-08',
#  '2016-09-09',
#  '2016-09-12',
#  '2016-09-13',
#  '2016-09-14',
#  '2016-09-15',
#  '2016-09-16',
#  '2016-09-19',
#  '2016-09-20',
#  '2016-09-21',
#  '2016-09-22',
#  '2016-09-23',
#  '2016-09-26',
#  '2016-09-27',
#  '2016-09-28',
#  '2016-09-29',
#  '2016-09-30',
#  '2016-10-03',
#  '2016-10-04',
#  '2016-10-05',
#  '2016-10-06',
#  '2016-10-07',
#  '2016-10-10',
#  '2016-10-11',
#  '2016-10-12',
#  '2016-10-13',
#  '2016-10-14',
#  '2016-10-17',
#  '2016-10-18',
#  '2016-10-19',
#  '2016-10-20',
#  '2016-10-21',
#  '2016-10-24',
#  '2016-10-25',
#  '2016-10-26',
#  '2016-10-27',
#  '2016-10-28',
#  '2016-10-31',
#  '2016-11-01',
#  '2016-11-02',
#  '2016-11-03',
#  '2016-11-04',
#  '2016-11-07',
#  '2016-11-08',
#  '2016-11-09',
#  '2016-11-10',
#  '2016-11-11',
#  '2016-11-14',
#  '2016-11-15',
#  '2016-11-16',
#  '2016-11-17',
#  '2016-11-18',
#  '2016-11-21',
#  '2016-11-22',
#  '2016-11-23',
#  '2016-11-25',
#  '2016-11-28',
#  '2016-11-29',
#  '2016-11-30',
#  '2016-12-01',
#  '2016-12-02',
#  '2016-12-05',
#  '2016-12-06',
#  '2016-12-07',
#  '2016-12-08',
#  '2016-12-09',
#  '2016-12-12',
#  '2016-12-13',
#  '2016-12-14',
#  '2016-12-15',
#  '2016-12-16',
#  '2016-12-19',
#  '2016-12-20',
#  '2016-12-21',
#  '2016-12-22',
#  '2017-08-04',
#  '2017-08-07',
#  '2017-08-08',
#  '2017-08-09',
#  '2017-08-10',
#  '2017-08-11',
#  '2017-08-14',
#  '2017-08-15',
#  '2017-08-16',
#  '2017-08-17',
#  '2017-08-18',
#  '2017-08-21',
#  '2017-08-22',
#  '2017-08-23',
#  '2017-08-24',
#  '2017-08-25',
#  '2017-08-28',
#  '2017-08-29',
#  '2017-08-30',
#  '2017-08-31',
#  '2017-09-01',
#  '2017-09-05',
#  '2017-09-06',
#  '2017-09-07',
#  '2017-09-08',
#  '2017-09-11',
#  '2017-09-12',
#  '2017-09-13',
#  '2017-09-14',
#  '2017-09-15',
#  '2017-09-18',
#  '2017-09-19',
#  '2017-09-20',
#  '2017-09-21',
#  '2017-09-22',
#  '2017-09-25',
#  '2017-09-26',
#  '2017-09-27',
#  '2017-09-28',
#  '2017-09-29',
#  '2017-10-02',
#  '2017-10-03',
#  '2017-10-04',
#  '2017-10-05',
#  '2017-10-06',
#  '2017-10-09',
#  '2017-10-10',
#  '2017-10-11',
#  '2017-10-12',
#  '2017-10-13',
#  '2017-10-16',
#  '2017-10-17',
#  '2017-10-18',
#  '2017-10-19',
#  '2017-10-20',
#  '2017-10-23',
#  '2017-10-24',
#  '2017-10-25',
#  '2017-10-26',
#  '2017-10-27',
#  '2017-10-30',
#  '2017-10-31',
#  '2017-11-01',
#  '2017-11-02',
#  '2017-11-03',
#  '2017-11-06',
#  '2017-11-07',
#  '2017-11-08',
#  '2017-11-09',
#  '2017-11-10',
#  '2017-11-13',
#  '2017-11-14',
#  '2017-11-15',
#  '2017-11-16',
#  '2017-11-17',
#  '2017-11-20',
#  '2017-11-21',
#  '2017-11-22',
#  '2017-11-24',
#  '2017-11-27',
#  '2017-11-28',
#  '2017-11-29',
#  '2017-11-30',
#  '2017-12-01',
#  '2017-12-04',
#  '2017-12-05',
#  '2017-12-06',
#  '2017-12-07',
#  '2017-12-08',
#  '2017-12-11',
#  '2017-12-12',
#  '2017-12-13',
#  '2017-12-14',
#  '2017-12-15',
#  '2017-12-18',
#  '2017-12-19',
#  ...]

# %%
xxx = futs[futs.symbol=='EC']
sorted(list(set(xxx[xxx.date=='2015-06-18'].name)))
# Out:
# ['CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Ratio Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Ratio Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Ratio Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Calendar-Weighted Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Calendar-Weighted Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Forwards Panama Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Forwards Panama Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Forwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Unadjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Unadjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Unadjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #2 (EC2) - Backwards Panama Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #2 (EC2) - Backwards Panama Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #2 (EC2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #2 (EC2) - Backwards Ratio Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #2 (EC2) - Backwards Ratio Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #2 (EC2) - Backwards Ratio Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #2 (EC2) - Calendar-Weighted Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #2 (EC2) - Calendar-Weighted Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #2 (EC2) - Forwards Panama Adjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #2 (EC2) - Forwards Panama Adjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #2 (EC2) - Forwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #2 (EC2) - Unadjusted Prices, Roll on First of Month',
#  'CME Euro FX Futures #2 (EC2) - Unadjusted Prices, Roll on Last Trading Day',
#  'CME Euro FX Futures #2 (EC2) - Unadjusted Prices, Roll on Open Interest Switch']

# %%
instruments = [
'CBOT Wheat Futures #2 (W2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CBOT Soybeans Futures #2 (S2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CBOT Corn Futures #2 (C2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CBOT 30-year US Treasury Bond Futures #1 (US1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CBOT 10-year US Treasury Note Futures #1 (TY1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME Japanese Yen JPY Futures #1 (JY1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME Mexican Peso Futures #1 (MP1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'NYMEX Gold Futures #1 (GC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'NYMEX WTI Crude Oil Futures #1 (CL1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME S&P 500 Index E-Mini Futures #1 (ES1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME NASDAQ 100 Index Mini Futures #1 (NQ1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'CME Canadian Dollar CAD Futures #1 (CD1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'EUREX Euro-Bund Futures #1 (FGBL1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
'EUREX DAX Futures #1 (FDAX1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch']

# %%
db = futs[futs.name.isin(instruments)]

# %%
db_final = db[['name', 'symbol', 'date', 'open', 'high', 'low', 'settle', 'volume']].sort_values(by=['name', 'date']).reset_index(drop=True)

# %%
list(set(db_final.name))
# Out:
# ['CME S&P 500 Index E-Mini Futures #1 (ES1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CBOT Corn Futures #2 (C2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'EUREX Euro-Bund Futures #1 (FGBL1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'NYMEX WTI Crude Oil Futures #1 (CL1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Euro FX Futures #1 (EC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Japanese Yen JPY Futures #1 (JY1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CBOT 30-year US Treasury Bond Futures #1 (US1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Canadian Dollar CAD Futures #1 (CD1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'NYMEX Gold Futures #1 (GC1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CBOT Wheat Futures #2 (W2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME NASDAQ 100 Index Mini Futures #1 (NQ1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CBOT Soybeans Futures #2 (S2) - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CME Mexican Peso Futures #1 (MP1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'CBOT 10-year US Treasury Note Futures #1 (TY1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch',
#  'EUREX DAX Futures #1 (FDAX1) - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch']

# %%
db_final_name = db_final.name.str.rstrip(' - Front Month - Backwards Panama Adjusted Prices, Roll on Open Interest Switch')

# %%
list(set(db_final_name))
# Out:
# ['CBOT Wheat Futures #2 (W2)',
#  'EUREX Euro-Bund Futures #1 (FGBL1)',
#  'CBOT Corn Futures #2 (C2)',
#  'CME Euro FX Futures #1 (EC1)',
#  'CBOT 30-year US Treasury Bond Futures #1 (US1)',
#  'CME NASDAQ 100 Index Mini Futures #1 (NQ1)',
#  'CME Japanese Yen JPY Futures #1 (JY1)',
#  'CME Mexican Peso Futures #1 (MP1)',
#  'CME Canadian Dollar CAD Futures #1 (CD1)',
#  'CBOT 10-year US Treasury Note Futures #1 (TY1)',
#  'EUREX DAX Futures #1 (FDAX1)',
#  'NYMEX Gold Futures #1 (GC1)',
#  'NYMEX WTI Crude Oil Futures #1 (CL1)',
#  'CME S&P 500 Index E-Mini Futures #1 (ES1)',
#  'CBOT Soybeans Futures #2 (S2)']
